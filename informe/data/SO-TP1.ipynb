# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ej = 'count_words concurrente'
tarch = 'tarch'
tmax = 'tmax'
ns = 'Tiempo en nanosegundos'

# %%
df = pd.read_csv('time-data.csv')
df = df.groupby([tarch, tmax, ej]).min().reset_index()

# %%
plt.clf()
dfPrueba = df[((df.tarch == 1) | (df.tarch == 2) | (df.tarch == 3))
              & ((df.tmax == 1) | (df.tmax == 2) | (df.tmax == 3))]
g = sns.FacetGrid(data=dfPrueba, col=tarch, row=tmax, sharey=True, size=5)
g = g.map(sns.barplot, ej, ns)
plt.show()
